# %%
# !pip install pandas
# !pip install dnspython
# Out:
# Requirement already satisfied: pandas in c:\users\jaime\appdata\local\programs\python\python310\lib\site-packages (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jaime\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jaime\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\jaime\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.22.2)
# Requirement already satisfied: six>=1.5 in c:\users\jaime\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\jaime\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Collecting dnspython
#   Downloading dnspython-2.2.0-py3-none-any.whl (266 kB)
# Installing collected packages: dnspython
# Successfully installed dnspython-2.2.0
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\jaime\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

# %%
accidentes_bicicletas=pd.read_csv("./AccidentesBicicletas_2021.csv", sep=";")

# %%
accidentes_bicicletas
# Out:
#     num_expediente       fecha      hora  \
# 0      2021S000047  01/01/2021  11:38:00
# 1      2021S000142  04/01/2021  11:30:00
# 2      2021S000142  04/01/2021  11:30:00
# 3      2021S000142  04/01/2021  11:30:00
# 4      2021S000142  04/01/2021  11:30:00
# ..             ...         ...       ...
# 840    2021S024926  29/12/2021  13:30:00
# 841    2021S024995  30/12/2021  21:00:00
# 842    2021S025055  30/12/2021  14:40:00
# 843    2021S025077  29/12/2021  23:10:00
# 844    2021S025094  29/12/2021  21:20:00
#
#                                           localizacion numero  cod_distrito  \
# 0    CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...     62            14
# 1     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 2     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 3     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 4     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# ..                                                 ...    ...           ...
# 840               AVDA. RAMON Y CAJAL / PASEO. CEREZOS     81             5
# 841                               CALL. BERRUGUETE, 22     22             6
# 842                            CALL. ENTRE ARROYOS, 11     11            14
# 843          CALL. TOMELLOSO / CALL. CRISTO DE LA VEGA     63            12
# 844  CALL. ALFREDO MARQUERIE / AVDA. CARDENAL HERRE...      1             8
#
#                 distrito           tipo_accidente estado_meteorológico  \
# 0              MORATALAZ                    Caída            Despejado
# 1    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 2    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 3    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 4    SAN BLAS-CANILLEJAS                    Caída            Despejado
# ..                   ...                      ...                  ...
# 840            CHAMARTÍN                    Caída            Despejado
# 841               TETUÁN                    Caída            Despejado
# 842            MORATALAZ                    Caída            Despejado
# 843                USERA  Colisión fronto-lateral            Despejado
# 844  FUENCARRAL-EL PARDO         Colisión lateral                  NaN
#
#     tipo_vehículo tipo_persona       rango_edad    sexo  cod_lesividad  \
# 0       Bicicleta    Conductor  De 45 a 49 años  Hombre            2.0
# 1       Bicicleta    Conductor  De 15 a 17 años  Hombre           14.0
# 2       Bicicleta    Conductor  De 18 a 20 años  Hombre           14.0
# 3       Bicicleta    Conductor  De 21 a 24 años  Hombre           14.0
# 4       Bicicleta    Conductor  De 50 a 54 años  Hombre            6.0
# ..            ...          ...              ...     ...            ...
# 840     Bicicleta    Conductor  De 50 a 54 años  Hombre            2.0
# 841     Bicicleta    Conductor  De 25 a 29 años   Mujer            NaN
# 842     Bicicleta    Conductor  De 30 a 34 años   Mujer           14.0
# 843     Bicicleta    Conductor  De 21 a 24 años  Hombre            7.0
# 844     Bicicleta    Conductor  De 50 a 54 años  Hombre            NaN
#
#                                         tipo_lesividad coordenada_x_utm  \
# 0                  Ingreso inferior o igual a 24 horas      446.426.917
# 1                             Sin asistencia sanitaria      448.606.811
# 2                             Sin asistencia sanitaria      448.606.811
# 3                             Sin asistencia sanitaria      448.606.811
# 4    Asistencia sanitaria inmediata en centro de sa...      448.606.811
# ..                                                 ...              ...
# 840                Ingreso inferior o igual a 24 horas      443.594.681
# 841                                                NaN      440.291.735
# 842                           Sin asistencia sanitaria      444.385.821
# 843  Asistencia sanitaria sólo en el lugar del acci...      440.557.175
# 844                                                NaN      440.451.148
#
#     coordenada_y_utm positiva_alcohol  positiva_droga
# 0      4.473.586.644                N             NaN
# 1      4.476.216.426                N             NaN
# 2      4.476.216.426                N             NaN
# 3      4.476.216.426                N             NaN
# 4      4.476.216.426                N             NaN
# ..               ...              ...             ...
# 840    4.478.221.621                N             NaN
# 841    4.478.733.191                N             NaN
# 842    4.473.305.098                N             NaN
# 843    4.470.111.030                N             NaN
# 844    4.482.181.906                N             NaN
#
# [845 rows x 19 columns]

# %%
drogas = accidentes_bicicletas["positiva_droga"]

# %%
drogas
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 840   NaN
# 841   NaN
# 842   NaN
# 843   NaN
# 844   NaN
# Name: positiva_droga, Length: 845, dtype: float64

# %%
drogas.unique()
# Out:
# array([nan])

# %%
#Eliminamos positiva drogas al ver que siempre es nan
accidentes_bicicletas_clean = accidentes_bicicletas.drop(labels=['positiva_droga'], axis=1, inplace=False)

# %%
accidentes_bicicletas_clean
# Out:
#     num_expediente       fecha      hora  \
# 0      2021S000047  01/01/2021  11:38:00
# 1      2021S000142  04/01/2021  11:30:00
# 2      2021S000142  04/01/2021  11:30:00
# 3      2021S000142  04/01/2021  11:30:00
# 4      2021S000142  04/01/2021  11:30:00
# ..             ...         ...       ...
# 840    2021S024926  29/12/2021  13:30:00
# 841    2021S024995  30/12/2021  21:00:00
# 842    2021S025055  30/12/2021  14:40:00
# 843    2021S025077  29/12/2021  23:10:00
# 844    2021S025094  29/12/2021  21:20:00
#
#                                           localizacion numero  cod_distrito  \
# 0    CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...     62            14
# 1     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 2     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 3     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# 4     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20      1            20
# ..                                                 ...    ...           ...
# 840               AVDA. RAMON Y CAJAL / PASEO. CEREZOS     81             5
# 841                               CALL. BERRUGUETE, 22     22             6
# 842                            CALL. ENTRE ARROYOS, 11     11            14
# 843          CALL. TOMELLOSO / CALL. CRISTO DE LA VEGA     63            12
# 844  CALL. ALFREDO MARQUERIE / AVDA. CARDENAL HERRE...      1             8
#
#                 distrito           tipo_accidente estado_meteorológico  \
# 0              MORATALAZ                    Caída            Despejado
# 1    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 2    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 3    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 4    SAN BLAS-CANILLEJAS                    Caída            Despejado
# ..                   ...                      ...                  ...
# 840            CHAMARTÍN                    Caída            Despejado
# 841               TETUÁN                    Caída            Despejado
# 842            MORATALAZ                    Caída            Despejado
# 843                USERA  Colisión fronto-lateral            Despejado
# 844  FUENCARRAL-EL PARDO         Colisión lateral                  NaN
#
#     tipo_vehículo tipo_persona       rango_edad    sexo  cod_lesividad  \
# 0       Bicicleta    Conductor  De 45 a 49 años  Hombre            2.0
# 1       Bicicleta    Conductor  De 15 a 17 años  Hombre           14.0
# 2       Bicicleta    Conductor  De 18 a 20 años  Hombre           14.0
# 3       Bicicleta    Conductor  De 21 a 24 años  Hombre           14.0
# 4       Bicicleta    Conductor  De 50 a 54 años  Hombre            6.0
# ..            ...          ...              ...     ...            ...
# 840     Bicicleta    Conductor  De 50 a 54 años  Hombre            2.0
# 841     Bicicleta    Conductor  De 25 a 29 años   Mujer            NaN
# 842     Bicicleta    Conductor  De 30 a 34 años   Mujer           14.0
# 843     Bicicleta    Conductor  De 21 a 24 años  Hombre            7.0
# 844     Bicicleta    Conductor  De 50 a 54 años  Hombre            NaN
#
#                                         tipo_lesividad coordenada_x_utm  \
# 0                  Ingreso inferior o igual a 24 horas      446.426.917
# 1                             Sin asistencia sanitaria      448.606.811
# 2                             Sin asistencia sanitaria      448.606.811
# 3                             Sin asistencia sanitaria      448.606.811
# 4    Asistencia sanitaria inmediata en centro de sa...      448.606.811
# ..                                                 ...              ...
# 840                Ingreso inferior o igual a 24 horas      443.594.681
# 841                                                NaN      440.291.735
# 842                           Sin asistencia sanitaria      444.385.821
# 843  Asistencia sanitaria sólo en el lugar del acci...      440.557.175
# 844                                                NaN      440.451.148
#
#     coordenada_y_utm positiva_alcohol
# 0      4.473.586.644                N
# 1      4.476.216.426                N
# 2      4.476.216.426                N
# 3      4.476.216.426                N
# 4      4.476.216.426                N
# ..               ...              ...
# 840    4.478.221.621                N
# 841    4.478.733.191                N
# 842    4.473.305.098                N
# 843    4.470.111.030                N
# 844    4.482.181.906                N
#
# [845 rows x 18 columns]

# %%
# Tampoco nos interesa el numero de la calle en que se produjo el acciente
accidentes_bicicletas_clean.drop(labels=['numero'], axis=1, inplace=True)

# %%
accidentes_bicicletas_clean
# Out:
#     num_expediente       fecha      hora  \
# 0      2021S000047  01/01/2021  11:38:00
# 1      2021S000142  04/01/2021  11:30:00
# 2      2021S000142  04/01/2021  11:30:00
# 3      2021S000142  04/01/2021  11:30:00
# 4      2021S000142  04/01/2021  11:30:00
# ..             ...         ...       ...
# 840    2021S024926  29/12/2021  13:30:00
# 841    2021S024995  30/12/2021  21:00:00
# 842    2021S025055  30/12/2021  14:40:00
# 843    2021S025077  29/12/2021  23:10:00
# 844    2021S025094  29/12/2021  21:20:00
#
#                                           localizacion  cod_distrito  \
# 0    CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...            14
# 1     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20            20
# 2     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20            20
# 3     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20            20
# 4     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20            20
# ..                                                 ...           ...
# 840               AVDA. RAMON Y CAJAL / PASEO. CEREZOS             5
# 841                               CALL. BERRUGUETE, 22             6
# 842                            CALL. ENTRE ARROYOS, 11            14
# 843          CALL. TOMELLOSO / CALL. CRISTO DE LA VEGA            12
# 844  CALL. ALFREDO MARQUERIE / AVDA. CARDENAL HERRE...             8
#
#                 distrito           tipo_accidente estado_meteorológico  \
# 0              MORATALAZ                    Caída            Despejado
# 1    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 2    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 3    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 4    SAN BLAS-CANILLEJAS                    Caída            Despejado
# ..                   ...                      ...                  ...
# 840            CHAMARTÍN                    Caída            Despejado
# 841               TETUÁN                    Caída            Despejado
# 842            MORATALAZ                    Caída            Despejado
# 843                USERA  Colisión fronto-lateral            Despejado
# 844  FUENCARRAL-EL PARDO         Colisión lateral                  NaN
#
#     tipo_vehículo tipo_persona       rango_edad    sexo  cod_lesividad  \
# 0       Bicicleta    Conductor  De 45 a 49 años  Hombre            2.0
# 1       Bicicleta    Conductor  De 15 a 17 años  Hombre           14.0
# 2       Bicicleta    Conductor  De 18 a 20 años  Hombre           14.0
# 3       Bicicleta    Conductor  De 21 a 24 años  Hombre           14.0
# 4       Bicicleta    Conductor  De 50 a 54 años  Hombre            6.0
# ..            ...          ...              ...     ...            ...
# 840     Bicicleta    Conductor  De 50 a 54 años  Hombre            2.0
# 841     Bicicleta    Conductor  De 25 a 29 años   Mujer            NaN
# 842     Bicicleta    Conductor  De 30 a 34 años   Mujer           14.0
# 843     Bicicleta    Conductor  De 21 a 24 años  Hombre            7.0
# 844     Bicicleta    Conductor  De 50 a 54 años  Hombre            NaN
#
#                                         tipo_lesividad coordenada_x_utm  \
# 0                  Ingreso inferior o igual a 24 horas      446.426.917
# 1                             Sin asistencia sanitaria      448.606.811
# 2                             Sin asistencia sanitaria      448.606.811
# 3                             Sin asistencia sanitaria      448.606.811
# 4    Asistencia sanitaria inmediata en centro de sa...      448.606.811
# ..                                                 ...              ...
# 840                Ingreso inferior o igual a 24 horas      443.594.681
# 841                                                NaN      440.291.735
# 842                           Sin asistencia sanitaria      444.385.821
# 843  Asistencia sanitaria sólo en el lugar del acci...      440.557.175
# 844                                                NaN      440.451.148
#
#     coordenada_y_utm positiva_alcohol
# 0      4.473.586.644                N
# 1      4.476.216.426                N
# 2      4.476.216.426                N
# 3      4.476.216.426                N
# 4      4.476.216.426                N
# ..               ...              ...
# 840    4.478.221.621                N
# 841    4.478.733.191                N
# 842    4.473.305.098                N
# 843    4.470.111.030                N
# 844    4.482.181.906                N
#
# [845 rows x 17 columns]

# %%
#Tampoco nos importa el código de distrito siempre y cuando tengamos el nombre del distrito
accidentes_bicicletas_clean.drop(labels=['cod_distrito'], axis=1, inplace=True)

# %%
accidentes_bicicletas_clean
# Out:
#     num_expediente       fecha      hora  \
# 0      2021S000047  01/01/2021  11:38:00
# 1      2021S000142  04/01/2021  11:30:00
# 2      2021S000142  04/01/2021  11:30:00
# 3      2021S000142  04/01/2021  11:30:00
# 4      2021S000142  04/01/2021  11:30:00
# ..             ...         ...       ...
# 840    2021S024926  29/12/2021  13:30:00
# 841    2021S024995  30/12/2021  21:00:00
# 842    2021S025055  30/12/2021  14:40:00
# 843    2021S025077  29/12/2021  23:10:00
# 844    2021S025094  29/12/2021  21:20:00
#
#                                           localizacion             distrito  \
# 0    CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...            MORATALAZ
# 1     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 2     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 3     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 4     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# ..                                                 ...                  ...
# 840               AVDA. RAMON Y CAJAL / PASEO. CEREZOS            CHAMARTÍN
# 841                               CALL. BERRUGUETE, 22               TETUÁN
# 842                            CALL. ENTRE ARROYOS, 11            MORATALAZ
# 843          CALL. TOMELLOSO / CALL. CRISTO DE LA VEGA                USERA
# 844  CALL. ALFREDO MARQUERIE / AVDA. CARDENAL HERRE...  FUENCARRAL-EL PARDO
#
#               tipo_accidente estado_meteorológico tipo_vehículo tipo_persona  \
# 0                      Caída            Despejado     Bicicleta    Conductor
# 1                      Caída            Despejado     Bicicleta    Conductor
# 2                      Caída            Despejado     Bicicleta    Conductor
# 3                      Caída            Despejado     Bicicleta    Conductor
# 4                      Caída            Despejado     Bicicleta    Conductor
# ..                       ...                  ...           ...          ...
# 840                    Caída            Despejado     Bicicleta    Conductor
# 841                    Caída            Despejado     Bicicleta    Conductor
# 842                    Caída            Despejado     Bicicleta    Conductor
# 843  Colisión fronto-lateral            Despejado     Bicicleta    Conductor
# 844         Colisión lateral                  NaN     Bicicleta    Conductor
#
#           rango_edad    sexo  cod_lesividad  \
# 0    De 45 a 49 años  Hombre            2.0
# 1    De 15 a 17 años  Hombre           14.0
# 2    De 18 a 20 años  Hombre           14.0
# 3    De 21 a 24 años  Hombre           14.0
# 4    De 50 a 54 años  Hombre            6.0
# ..               ...     ...            ...
# 840  De 50 a 54 años  Hombre            2.0
# 841  De 25 a 29 años   Mujer            NaN
# 842  De 30 a 34 años   Mujer           14.0
# 843  De 21 a 24 años  Hombre            7.0
# 844  De 50 a 54 años  Hombre            NaN
#
#                                         tipo_lesividad coordenada_x_utm  \
# 0                  Ingreso inferior o igual a 24 horas      446.426.917
# 1                             Sin asistencia sanitaria      448.606.811
# 2                             Sin asistencia sanitaria      448.606.811
# 3                             Sin asistencia sanitaria      448.606.811
# 4    Asistencia sanitaria inmediata en centro de sa...      448.606.811
# ..                                                 ...              ...
# 840                Ingreso inferior o igual a 24 horas      443.594.681
# 841                                                NaN      440.291.735
# 842                           Sin asistencia sanitaria      444.385.821
# 843  Asistencia sanitaria sólo en el lugar del acci...      440.557.175
# 844                                                NaN      440.451.148
#
#     coordenada_y_utm positiva_alcohol
# 0      4.473.586.644                N
# 1      4.476.216.426                N
# 2      4.476.216.426                N
# 3      4.476.216.426                N
# 4      4.476.216.426                N
# ..               ...              ...
# 840    4.478.221.621                N
# 841    4.478.733.191                N
# 842    4.473.305.098                N
# 843    4.470.111.030                N
# 844    4.482.181.906                N
#
# [845 rows x 16 columns]

# %%
rangos_edad=accidentes_bicicletas_clean["rango_edad"]
rangos_edad
# Out:
# 0      De 45 a 49 años
# 1      De 15 a 17 años
# 2      De 18 a 20 años
# 3      De 21 a 24 años
# 4      De 50 a 54 años
#             ...
# 840    De 50 a 54 años
# 841    De 25 a 29 años
# 842    De 30 a 34 años
# 843    De 21 a 24 años
# 844    De 50 a 54 años
# Name: rango_edad, Length: 845, dtype: object

# %%
rangos_edad.unique()
# Out:
# array(['De 45 a 49 años', 'De 15 a 17 años', 'De 18 a 20 años',
#        'De 21 a 24 años', 'De 50 a 54 años', 'De 40 a 44 años',
#        'De 35 a 39 años', 'De 60 a 64 años', 'De 25 a 29 años',
#        'De 30 a 34 años', 'Desconocido', 'De 6 a 9 años',
#        'De 55 a 59 años', 'De 10 a 14 años', 'De 70 a 74 años',
#        'Más de 74 años', 'Menor de 5 años', 'De 65 a 69 años'],
#       dtype=object)

# %%
codigos_lesividades=accidentes_bicicletas_clean["cod_lesividad"]
codigos_lesividades
# Out:
# 0       2.0
# 1      14.0
# 2      14.0
# 3      14.0
# 4       6.0
#        ...
# 840     2.0
# 841     NaN
# 842    14.0
# 843     7.0
# 844     NaN
# Name: cod_lesividad, Length: 845, dtype: float64

# %%
tipos_lesividad=accidentes_bicicletas_clean["tipo_lesividad"]
tipos_lesividad
# Out:
# 0                    Ingreso inferior o igual a 24 horas
# 1                               Sin asistencia sanitaria
# 2                               Sin asistencia sanitaria
# 3                               Sin asistencia sanitaria
# 4      Asistencia sanitaria inmediata en centro de sa...
#                              ...
# 840                  Ingreso inferior o igual a 24 horas
# 841                                                  NaN
# 842                             Sin asistencia sanitaria
# 843    Asistencia sanitaria sólo en el lugar del acci...
# 844                                                  NaN
# Name: tipo_lesividad, Length: 845, dtype: object

# %%
#Limpiamos tambien tipo lesividad porque tenemos un equivalente numerico con el que sera mas facil de trabajar
accidentes_bicicletas_clean.drop(labels="tipo_lesividad", axis=1, inplace=True)
accidentes_bicicletas_clean
# Out:
#     num_expediente       fecha      hora  \
# 0      2021S000047  01/01/2021  11:38:00
# 1      2021S000142  04/01/2021  11:30:00
# 2      2021S000142  04/01/2021  11:30:00
# 3      2021S000142  04/01/2021  11:30:00
# 4      2021S000142  04/01/2021  11:30:00
# ..             ...         ...       ...
# 840    2021S024926  29/12/2021  13:30:00
# 841    2021S024995  30/12/2021  21:00:00
# 842    2021S025055  30/12/2021  14:40:00
# 843    2021S025077  29/12/2021  23:10:00
# 844    2021S025094  29/12/2021  21:20:00
#
#                                           localizacion             distrito  \
# 0    CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...            MORATALAZ
# 1     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 2     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 3     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 4     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# ..                                                 ...                  ...
# 840               AVDA. RAMON Y CAJAL / PASEO. CEREZOS            CHAMARTÍN
# 841                               CALL. BERRUGUETE, 22               TETUÁN
# 842                            CALL. ENTRE ARROYOS, 11            MORATALAZ
# 843          CALL. TOMELLOSO / CALL. CRISTO DE LA VEGA                USERA
# 844  CALL. ALFREDO MARQUERIE / AVDA. CARDENAL HERRE...  FUENCARRAL-EL PARDO
#
#               tipo_accidente estado_meteorológico tipo_vehículo tipo_persona  \
# 0                      Caída            Despejado     Bicicleta    Conductor
# 1                      Caída            Despejado     Bicicleta    Conductor
# 2                      Caída            Despejado     Bicicleta    Conductor
# 3                      Caída            Despejado     Bicicleta    Conductor
# 4                      Caída            Despejado     Bicicleta    Conductor
# ..                       ...                  ...           ...          ...
# 840                    Caída            Despejado     Bicicleta    Conductor
# 841                    Caída            Despejado     Bicicleta    Conductor
# 842                    Caída            Despejado     Bicicleta    Conductor
# 843  Colisión fronto-lateral            Despejado     Bicicleta    Conductor
# 844         Colisión lateral                  NaN     Bicicleta    Conductor
#
#           rango_edad    sexo  cod_lesividad coordenada_x_utm coordenada_y_utm  \
# 0    De 45 a 49 años  Hombre            2.0      446.426.917    4.473.586.644
# 1    De 15 a 17 años  Hombre           14.0      448.606.811    4.476.216.426
# 2    De 18 a 20 años  Hombre           14.0      448.606.811    4.476.216.426
# 3    De 21 a 24 años  Hombre           14.0      448.606.811    4.476.216.426
# 4    De 50 a 54 años  Hombre            6.0      448.606.811    4.476.216.426
# ..               ...     ...            ...              ...              ...
# 840  De 50 a 54 años  Hombre            2.0      443.594.681    4.478.221.621
# 841  De 25 a 29 años   Mujer            NaN      440.291.735    4.478.733.191
# 842  De 30 a 34 años   Mujer           14.0      444.385.821    4.473.305.098
# 843  De 21 a 24 años  Hombre            7.0      440.557.175    4.470.111.030
# 844  De 50 a 54 años  Hombre            NaN      440.451.148    4.482.181.906
#
#     positiva_alcohol
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ..               ...
# 840                N
# 841                N
# 842                N
# 843                N
# 844                N
#
# [845 rows x 15 columns]

# %%
accidentes_bicicletas_clean.drop(labels=["coordenada_x_utm", "coordenada_y_utm"], axis=1, inplace=True)
accidentes_bicicletas_clean
# Out:
#     num_expediente       fecha      hora  \
# 0      2021S000047  01/01/2021  11:38:00
# 1      2021S000142  04/01/2021  11:30:00
# 2      2021S000142  04/01/2021  11:30:00
# 3      2021S000142  04/01/2021  11:30:00
# 4      2021S000142  04/01/2021  11:30:00
# ..             ...         ...       ...
# 840    2021S024926  29/12/2021  13:30:00
# 841    2021S024995  30/12/2021  21:00:00
# 842    2021S025055  30/12/2021  14:40:00
# 843    2021S025077  29/12/2021  23:10:00
# 844    2021S025094  29/12/2021  21:20:00
#
#                                           localizacion             distrito  \
# 0    CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...            MORATALAZ
# 1     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 2     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 3     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# 4     PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20  SAN BLAS-CANILLEJAS
# ..                                                 ...                  ...
# 840               AVDA. RAMON Y CAJAL / PASEO. CEREZOS            CHAMARTÍN
# 841                               CALL. BERRUGUETE, 22               TETUÁN
# 842                            CALL. ENTRE ARROYOS, 11            MORATALAZ
# 843          CALL. TOMELLOSO / CALL. CRISTO DE LA VEGA                USERA
# 844  CALL. ALFREDO MARQUERIE / AVDA. CARDENAL HERRE...  FUENCARRAL-EL PARDO
#
#               tipo_accidente estado_meteorológico tipo_vehículo tipo_persona  \
# 0                      Caída            Despejado     Bicicleta    Conductor
# 1                      Caída            Despejado     Bicicleta    Conductor
# 2                      Caída            Despejado     Bicicleta    Conductor
# 3                      Caída            Despejado     Bicicleta    Conductor
# 4                      Caída            Despejado     Bicicleta    Conductor
# ..                       ...                  ...           ...          ...
# 840                    Caída            Despejado     Bicicleta    Conductor
# 841                    Caída            Despejado     Bicicleta    Conductor
# 842                    Caída            Despejado     Bicicleta    Conductor
# 843  Colisión fronto-lateral            Despejado     Bicicleta    Conductor
# 844         Colisión lateral                  NaN     Bicicleta    Conductor
#
#           rango_edad    sexo  cod_lesividad positiva_alcohol
# 0    De 45 a 49 años  Hombre            2.0                N
# 1    De 15 a 17 años  Hombre           14.0                N
# 2    De 18 a 20 años  Hombre           14.0                N
# 3    De 21 a 24 años  Hombre           14.0                N
# 4    De 50 a 54 años  Hombre            6.0                N
# ..               ...     ...            ...              ...
# 840  De 50 a 54 años  Hombre            2.0                N
# 841  De 25 a 29 años   Mujer            NaN                N
# 842  De 30 a 34 años   Mujer           14.0                N
# 843  De 21 a 24 años  Hombre            7.0                N
# 844  De 50 a 54 años  Hombre            NaN                N
#
# [845 rows x 13 columns]

# %%
accidentes_bicicletas_clean.drop(labels="num_expediente", axis=1, inplace=True)
accidentes_bicicletas_clean
# Out:
#           fecha      hora                                       localizacion  \
# 0    01/01/2021  11:38:00  CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRI...
# 1    04/01/2021  11:30:00   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20
# 2    04/01/2021  11:30:00   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20
# 3    04/01/2021  11:30:00   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20
# 4    04/01/2021  11:30:00   PLAZA. GRECIA / AVDA. ARCENTALES wanda farola 20
# ..          ...       ...                                                ...
# 840  29/12/2021  13:30:00               AVDA. RAMON Y CAJAL / PASEO. CEREZOS
# 841  30/12/2021  21:00:00                               CALL. BERRUGUETE, 22
# 842  30/12/2021  14:40:00                            CALL. ENTRE ARROYOS, 11
# 843  29/12/2021  23:10:00          CALL. TOMELLOSO / CALL. CRISTO DE LA VEGA
# 844  29/12/2021  21:20:00  CALL. ALFREDO MARQUERIE / AVDA. CARDENAL HERRE...
#
#                 distrito           tipo_accidente estado_meteorológico  \
# 0              MORATALAZ                    Caída            Despejado
# 1    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 2    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 3    SAN BLAS-CANILLEJAS                    Caída            Despejado
# 4    SAN BLAS-CANILLEJAS                    Caída            Despejado
# ..                   ...                      ...                  ...
# 840            CHAMARTÍN                    Caída            Despejado
# 841               TETUÁN                    Caída            Despejado
# 842            MORATALAZ                    Caída            Despejado
# 843                USERA  Colisión fronto-lateral            Despejado
# 844  FUENCARRAL-EL PARDO         Colisión lateral                  NaN
#
#     tipo_vehículo tipo_persona       rango_edad    sexo  cod_lesividad  \
# 0       Bicicleta    Conductor  De 45 a 49 años  Hombre            2.0
# 1       Bicicleta    Conductor  De 15 a 17 años  Hombre           14.0
# 2       Bicicleta    Conductor  De 18 a 20 años  Hombre           14.0
# 3       Bicicleta    Conductor  De 21 a 24 años  Hombre           14.0
# 4       Bicicleta    Conductor  De 50 a 54 años  Hombre            6.0
# ..            ...          ...              ...     ...            ...
# 840     Bicicleta    Conductor  De 50 a 54 años  Hombre            2.0
# 841     Bicicleta    Conductor  De 25 a 29 años   Mujer            NaN
# 842     Bicicleta    Conductor  De 30 a 34 años   Mujer           14.0
# 843     Bicicleta    Conductor  De 21 a 24 años  Hombre            7.0
# 844     Bicicleta    Conductor  De 50 a 54 años  Hombre            NaN
#
#     positiva_alcohol
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N
# ..               ...
# 840                N
# 841                N
# 842                N
# 843                N
# 844                N
#
# [845 rows x 12 columns]

# %%
tipos_de_sexo = accidentes_bicicletas_clean["sexo"]
tipos_de_sexo.unique()
# Out:
# array(['Hombre', 'Mujer', 'Desconocido'], dtype=object)

# %%
rangos_edad=accidentes_bicicletas_clean["rango_edad"]
rangos_edad.info
# Out:
# <bound method Series.info of 0      De 45 a 49 años
# 1      De 15 a 17 años
# 2      De 18 a 20 años
# 3      De 21 a 24 años
# 4      De 50 a 54 años
#             ...
# 840    De 50 a 54 años
# 841    De 25 a 29 años
# 842    De 30 a 34 años
# 843    De 21 a 24 años
# 844    De 50 a 54 años
# Name: rango_edad, Length: 845, dtype: object>

# %%
cods_lesividad=accidentes_bicicletas_clean["cod_lesividad"]
cods_lesividad_asInt =
# Out:
# 0       2.0
# 1      14.0
# 2      14.0
# 3      14.0
# 4       6.0
#        ...
# 840     2.0
# 841     NaN
# 842    14.0
# 843     7.0
# 844     NaN
# Name: cod_lesividad, Length: 845, dtype: float64

# %%
#Vamos a intentar la insercion en BBDD en la nube

# %%
# Instalar la librería pymongo, para trabajar con bases de datos no relacionales MongoDB
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.0.1-cp310-cp310-win_amd64.whl (354 kB)
# Installing collected packages: pymongo
# Successfully installed pymongo-4.0.1
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\jaime\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Se usa la librería pymongo
import pymongo

# %%
uri_mongo = "mongodb+srv://06miotaicaja:06miotaicaja@cluster0.cd2tm.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"

# %%
conexion = pymongo.MongoClient(uri_mongo)

# %%
todas_bbdd = conexion.list_database_names()
for bbdd in todas_bbdd:
    print(bbdd)
# Out:
# bicismadrid
# admin
# local

# %%
#Obtenemos (o creamos si no existe) la base de datos bicis madrid
base_datos = conexion.bicismadrid

# %%
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.cd2tm.mongodb.net:27017', 'cluster0-shard-00-00.cd2tm.mongodb.net:27017', 'cluster0-shard-00-02.cd2tm.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-xicyrh-shard-0', tls=True), 'bicislocas')

# %%
# Obtenemos (o creamos si no existe) la coleccion accidentes bicicleta
bicismadridaccidents = base_datos.bicismadridaccidents

# %%
#bicismadridcollection.insert_one(documento1)

# %%
#Inserta todos los valores del Dataframe de pandas como documentos en la coleccion bicismadridaccidents
bicismadridaccidents.insert_many(accidentes_bicicletas_clean.to_dict("records"))

# %%
#Observamos que la coleccion tiene documentos
print (base_datos.list_collection_names())
# Out:
# ['bicismadridaccidents']

# %%
#Devuelve algun documento
bicismadridaccidents.find_one()
# Out:
# {'_id': ObjectId('6217b5f8de917c21197d6810'),
#  'fecha': '01/01/2021',
#  'hora': '11:38:00',
#  'localizacion': 'CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRISTOBAL',
#  'distrito': 'MORATALAZ',
#  'tipo_accidente': 'Caída',
#  'estado_meteorológico': 'Despejado',
#  'tipo_vehículo': 'Bicicleta',
#  'tipo_persona': 'Conductor',
#  'rango_edad': 'De 45 a 49 años',
#  'sexo': 'Hombre',
#  'cod_lesividad': 2.0,
#  'positiva_alcohol': 'N'}

# %%
#bicismadridaccidents.drop()

# %%
# Consulta 1:Aquellos accidentes en los que el conductor estaba ebrio (no deberia haber ninguno)
for positive_in_alcohol in bicismadridaccidents.find({"positiva_alcohol":'Y'}):
     print(positive_in_alcohol)

# %%
# Consulta 2: Accidentes que se han dado en el distrito de Moratalaz
for accident in bicismadridaccidents.find({"distrito":'MORATALAZ'}):
     print(accident)
# Out:
# {'_id': ObjectId('6217b5f8de917c21197d6810'), 'fecha': '01/01/2021', 'hora': '11:38:00', 'localizacion': 'CALL. JOSE BERGAMIN / CALL. FLORENCIO CANO CRISTOBAL', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 45 a 49 años', 'sexo': 'Hombre', 'cod_lesividad': 2.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6836'), 'fecha': '31/01/2021', 'hora': '15:40:00', 'localizacion': 'CALL. ARROYO FONTARRON / CALL. ENCOMIENDA DE PALACIOS', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Lluvia débil', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 25 a 29 años', 'sexo': 'Hombre', 'cod_lesividad': 7.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d683e'), 'fecha': '06/02/2021', 'hora': '14:00:00', 'localizacion': 'PLAZA. CORREGIDOR SANCHO DE CORDOBA / CALL. ARROYO DE LAS PILILLAS', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Colisión lateral', 'estado_meteorológico': nan, 'tipo_vehículo': 'Bicicleta EPAC (pedaleo asistido)', 'tipo_persona': 'Conductor', 'rango_edad': 'De 30 a 34 años', 'sexo': 'Hombre', 'cod_lesividad': nan, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6860'), 'fecha': '21/02/2021', 'hora': '13:30:00', 'localizacion': 'CALL. ARROYO FONTARRON, 24', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Lluvia débil', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 45 a 49 años', 'sexo': 'Hombre', 'cod_lesividad': 2.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6877'), 'fecha': '04/03/2021', 'hora': '15:35:00', 'localizacion': 'CALL. FLORENCIO CANO CRISTOBAL / CALL. JOSE BERGAMIN', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Colisión fronto-lateral', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 15 a 17 años', 'sexo': 'Hombre', 'cod_lesividad': 14.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6878'), 'fecha': '03/03/2021', 'hora': '17:09:00', 'localizacion': 'CALL. BRUJAS / CALL. ATENAS', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Atropello a persona', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 50 a 54 años', 'sexo': 'Hombre', 'cod_lesividad': 14.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6879'), 'fecha': '03/03/2021', 'hora': '17:09:00', 'localizacion': 'CALL. BRUJAS / CALL. ATENAS', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Atropello a persona', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Peatón', 'rango_edad': 'Menor de 5 años', 'sexo': 'Hombre', 'cod_lesividad': 6.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6894'), 'fecha': '14/03/2021', 'hora': '15:45:00', 'localizacion': 'AVDA. DOCTOR GARCIA TAPIA / CALL. MARROQUINA', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Colisión fronto-lateral', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 18 a 20 años', 'sexo': 'Hombre', 'cod_lesividad': nan, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6942'), 'fecha': '16/05/2021', 'hora': '8:50:00', 'localizacion': 'AVDA. DOCTOR GARCIA TAPIA / AUTOV. M-40', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Colisión fronto-lateral', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 40 a 44 años', 'sexo': 'Hombre', 'cod_lesividad': 7.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d69a9'), 'fecha': '20/06/2021', 'hora': '18:55:00', 'localizacion': 'CALL. LUIS DE HOYOS SAINZ / CALL. VALDEBERNARDO', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Alcance', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 15 a 17 años', 'sexo': 'Hombre', 'cod_lesividad': 3.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d69ae'), 'fecha': '21/06/2021', 'hora': '20:39:00', 'localizacion': 'AVDA. DOCTOR GARCIA TAPIA, 232', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Choque contra obstáculo fijo', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 10 a 14 años', 'sexo': 'Hombre', 'cod_lesividad': 7.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d69c2'), 'fecha': '27/06/2021', 'hora': '10:30:00', 'localizacion': 'CALL. ENCOMIENDA DE PALACIOS, 1', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 18 a 20 años', 'sexo': 'Hombre', 'cod_lesividad': 7.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6a3a'), 'fecha': '25/08/2021', 'hora': '5:50:00', 'localizacion': 'CALL. ARROYO DE LA MEDIA LEGUA / CALL. ALCALDE GARRIDO JUARISTI', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 40 a 44 años', 'sexo': 'Hombre', 'cod_lesividad': 2.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6a4b'), 'fecha': '03/09/2021', 'hora': '19:35:00', 'localizacion': 'CALL. CORREGIDOR DIEGO DE VALDERRABANO / CALL. ALFREDO BRAÑAS', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Colisión fronto-lateral', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta EPAC (pedaleo asistido)', 'tipo_persona': 'Conductor', 'rango_edad': 'Desconocido', 'sexo': 'Desconocido', 'cod_lesividad': 14.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6a56'), 'fecha': '07/09/2021', 'hora': '12:30:00', 'localizacion': 'CALL. FUENTE CARRANTONA / AUTOV. M-23', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 21 a 24 años', 'sexo': 'Hombre', 'cod_lesividad': 7.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6ad0'), 'fecha': '17/10/2021', 'hora': '19:05:00', 'localizacion': 'CALL. BRUJAS / CALL. HACIENDA DE PAVONES', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 60 a 64 años', 'sexo': 'Mujer', 'cod_lesividad': 7.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6ae5'), 'fecha': '26/10/2021', 'hora': '8:00:00', 'localizacion': 'CALL. CAMINO DE LOS VINATEROS / CALL. CORREGIDOR DIEGO DE VALDERRABANO', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Colisión fronto-lateral', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 25 a 29 años', 'sexo': 'Mujer', 'cod_lesividad': 6.0, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6b28'), 'fecha': '01/12/2021', 'hora': '19:55:00', 'localizacion': 'AVDA. DOCTOR GARCIA TAPIA / CALL. AUGUSTO GONZALEZ BESADA', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Otro', 'estado_meteorológico': 'Lluvia débil', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 45 a 49 años', 'sexo': 'Hombre', 'cod_lesividad': nan, 'positiva_alcohol': 'N'}
# {'_id': ObjectId('6217b5f8de917c21197d6b5a'), 'fecha': '30/12/2021', 'hora': '14:40:00', 'localizacion': 'CALL. ENTRE ARROYOS, 11', 'distrito': 'MORATALAZ', 'tipo_accidente': 'Caída', 'estado_meteorológico': 'Despejado', 'tipo_vehículo': 'Bicicleta', 'tipo_persona': 'Conductor', 'rango_edad': 'De 30 a 34 años', 'sexo': 'Mujer', 'cod_lesividad': 14.0, 'positiva_alcohol': 'N'}

# %%
# Demasiado verborreico
# Otra cosulta: cuántos accidentes hubo en Moratalaz
bicismadridaccidents.count_documents({'distrito':'MORATALAZ'})
# Out:
# 19

# %%
# Accidentes que se producen con bicicleta electrica
accidentes_bici_normal = bicismadridaccidents.count_documents({'tipo_vehículo':"Bicicleta"})
accidentes_bici_electrica = bicismadridaccidents.count_documents({'tipo_vehículo':{"$ne" :"Bicicleta"}})
#Porcentaje de bicicletas electricas que tienen accidentes
porcentaje_accidentes_electrica = 100*(accidentes_bici_electrica/bicismadridaccidents.count_documents({}))
porcentaje_accidentes_electrica
# Out:
# 18.224852071005916

# %%
#Porcentaje accidentes bicis normales
porcentaje_accidentes_bici_normal = 100*(accidentes_bici_normal/bicismadridaccidents.count_documents({}))
porcentaje_accidentes_bici_normal
# Out:
# 81.77514792899409

# %%
#Consulta 2: Consultar los 3 distritos con mas accidentes
agregados = bicismadridaccidents.aggregate([{
    "$group": {
        "_id":"$distrito",
        "numero": {"$sum" : 1}
    }
    },
    {"$sort":
     { "numero": -1 }
    },
    {"$limit":3}
])
agregados
for agregado in agregados:
    print(agregado)
# Out:
# {'_id': 'CENTRO', 'numero': 102}
# {'_id': 'MONCLOA-ARAVACA', 'numero': 77}
# {'_id': 'SALAMANCA', 'numero': 66}

# %%
#Consulta 3 (parte 1): Encunetra la media de las lesividades
media_de_lesividad = bicismadridaccidents.aggregate([
      {
        "$match":{
            "cod_lesividad": {
                "$exists": True, 
                "$ne": np.nan
            }
        }
    },  
    {"$group": {
        "_id":"_id",
        #"Numero de accidentes": {"$sum" : 1},
        "Media de lesividad" :{"$avg": "$cod_lesividad"}
    }
    },
    {"$sort":
     { "numero": -1 }
    },
    {"$limit":1}
])
for media in media_de_lesividad:
    media_final=media
    
media = media_final['Media de lesividad']
media
# Out:
# 5.756164383561644

# %%
#Consulta 3(parte 2): Encuentra aquellos distritos cuya lesvidad sea mayor (a menor grado de lesividad mas probabilidad de ingreso hospitalario)
agregados_lesividad = bicismadridaccidents.aggregate([
      {
        "$match":{
            "cod_lesividad": {
                "$exists": True, 
                "$ne": np.nan,
                "$lt": media
            }
        }
    },  
    {"$group": {
        "_id":"$distrito",
        "Numero de accidentes": {"$sum" : 1},
        "Media de lesividad" :{"$avg": "$cod_lesividad"}
    }
    },
    {"$sort":
     { "numero": -1 }
    }
])
agregados_lesividad
for agregado in agregados_lesividad:
    print(agregado)
# Out:
# {'_id': 'ARGANZUELA', 'Numero de accidentes': 27, 'Media de lesividad': 1.7407407407407407}
# {'_id': 'CENTRO', 'Numero de accidentes': 35, 'Media de lesividad': 1.7428571428571429}
# {'_id': 'CARABANCHEL', 'Numero de accidentes': 9, 'Media de lesividad': 2.2222222222222223}
# {'_id': 'PUENTE DE VALLECAS', 'Numero de accidentes': 13, 'Media de lesividad': 1.6923076923076923}
# {'_id': 'HORTALEZA', 'Numero de accidentes': 10, 'Media de lesividad': 2.1}
# {'_id': 'VILLAVERDE', 'Numero de accidentes': 6, 'Media de lesividad': 1.8333333333333333}
# {'_id': 'BARAJAS', 'Numero de accidentes': 9, 'Media de lesividad': 1.8888888888888888}
# {'_id': 'MORATALAZ', 'Numero de accidentes': 4, 'Media de lesividad': 2.25}
# {'_id': 'CHAMBERÍ', 'Numero de accidentes': 17, 'Media de lesividad': 1.9411764705882353}
# {'_id': 'TETUÁN', 'Numero de accidentes': 10, 'Media de lesividad': 2.8}
# {'_id': 'SAN BLAS-CANILLEJAS', 'Numero de accidentes': 5, 'Media de lesividad': 2.2}
# {'_id': 'VICÁLVARO', 'Numero de accidentes': 8, 'Media de lesividad': 1.875}
# {'_id': 'VILLA DE VALLECAS', 'Numero de accidentes': 3, 'Media de lesividad': 1.6666666666666667}
# {'_id': 'LATINA', 'Numero de accidentes': 11, 'Media de lesividad': 2.090909090909091}
# {'_id': 'RETIRO', 'Numero de accidentes': 23, 'Media de lesividad': 1.7391304347826086}
# {'_id': 'CHAMARTÍN', 'Numero de accidentes': 16, 'Media de lesividad': 2.1875}
# {'_id': 'MONCLOA-ARAVACA', 'Numero de accidentes': 32, 'Media de lesividad': 2.0}
# {'_id': 'CIUDAD LINEAL', 'Numero de accidentes': 13, 'Media de lesividad': 2.1538461538461537}
# {'_id': 'SALAMANCA', 'Numero de accidentes': 22, 'Media de lesividad': 2.409090909090909}
# {'_id': 'FUENCARRAL-EL PARDO', 'Numero de accidentes': 18, 'Media de lesividad': 2.3333333333333335}
# {'_id': 'USERA', 'Numero de accidentes': 7, 'Media de lesividad': 1.5714285714285714}
